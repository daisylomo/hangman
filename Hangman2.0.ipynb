# %%
#importing modules
import time
from getpass import getpass

#set the guess word
word = str(getpass("Set the secret word: ")).lower()
time.sleep(3)

#asking for user input
name = input("Name: ")
print("Hello " + name,", Time to play Hangman!")

time.sleep(1)
print("Start guessing...")
time.sleep(0.5)

#create a variable with an empty value to store guessed characters
guesses = ""

#determine number of turns
turns = 10

#create a while loop
#check if the turns are more than 0

while turns > 0:
    #initialize a counter for incorrect guesses
    failed = 0
    
    #for every character in guess word
    for char in word:
        #see if character is in player guess
        if char in guesses:
            #print out the character
            print(char, end = " "),
        else:
            # if not found, print a dash
            print ("_", end = " "),     
       
        #increase the failed counter with one
            failed += 1    

    # if failed is equal to zero print You Won
    if failed == 0:        
        print ("You won")
    # exit the script
        break
    # ask the user to guess a character
    guess = input("guess a character:").lower()

    # set the players guess to guesses
    guesses += guess                   
    print(guesses)
    # if the guess is not found in the secret word
    if guess.lower() not in word:
     # turns counter decreases with 1 (now 9)
        turns -= 1        
 
    # print wrong
        print ("Wrong")  
 
    # how many turns are left
        print ("You have", + turns, 'more guesses' )
 
    # if the turns are equal to zero
        if turns == 0:           
    
        # print "You Lose"
            print ("You Lose"  )
# Out:
# Set the secret word: ········
# Name: d
# Hello d , Time to play Hangman!
# Start guessing...
# _ _ _ _ _ guess a character:c
# c
# c c _ _ _ guess a character:b
# cb
# c c _ b _ guess a character:v
# cbv
# Wrong
# You have 9 more guesses
# c c _ b _ guess a character:n
# cbvn
# c c _ b n guess a character:
# cbvn
# c c _ b n guess a character:m
# cbvnm
# c c m b n You won
